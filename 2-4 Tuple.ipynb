# %%
# tuple surrounds with ()
# tuple cannot change its value
t1 = ()

# %%
t2 = (1,) # need comma for single value tuple
t2
# Out:
# (1,)

# %%
t3 = (1,2,3)
t3
# Out:
# (1, 2, 3)

# %%
t4 = 1,2,3
t4
# Out:
# (1, 2, 3)

# %%
t5 = ('a', 'b', ('ab','cd'))
t5
# Out:
# ('a', 'b', ('ab', 'cd'))

# %%
t1 = (1,2,'a','b')
del t1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-e60ebcde2836> in <module>
#       1 t1 = (1,2,'a','b')
# ----> 2 del t1[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
t1 = (1,2,'a','b')
t1[0] = 'c'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-54d925f8271e> in <module>
#       1 t1 = (1,2,'a','b')
# ----> 2 t1[0] = 'c'
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1 = (1,2,'a','b')
t1[0]
# Out:
# 1

# %%
t1[3]
# Out:
# 'b'

# %%
t1[1:]
# Out:
# (2, 'a', 'b')

# %%
t2 = (3,4)
t1 + t2
# Out:
# (1, 2, 'a', 'b', 3, 4)

# %%
t2 * 3
# Out:
# (3, 4, 3, 4, 3, 4)

# %%
t1 = (1,2,'a','b')
len(t1)
# Out:
# 4

# %%
t1 = (1,2,3)
t2 = t1 + (4,)
t2
# Out:
# (1, 2, 3, 4)
