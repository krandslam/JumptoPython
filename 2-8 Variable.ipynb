# %%
a = 1
b = "python"
c = [1,2,3]

# %%
a = [1,2,3]

# %%
id(a) # pointer - address of variable a
# Out:
# 140168445202368

# %%
a = [1,2,3]
b = a

# %%
id(a)
# Out:
# 140168211892608

# %%
id(b)
# Out:
# 140168211892608

# %%
a is b # check whether same comparing variable is pointing same address
# Out:
# True

# %%
a[1] = 4

# %%
a
# Out:
# [1, 4, 3]

# %%
b
# Out:
# [1, 4, 3]

# %%
# how to differentiate a and b

# %%
# 1. use [:]

a = [1,2,3]
b = a[:]
a[1] = 4

# %%
a
# Out:
# [1, 4, 3]

# %%
b
# Out:
# [1, 2, 3]

# %%
# use copy module

# %%
from copy import copy

# %%
a = [1,2,3]

# %%
b = copy(a)

# %%
a
# Out:
# [1, 2, 3]

# %%
b
# Out:
# [1, 2, 3]

# %%
b is a
# Out:
# False

# %%
a, b = ('python', 'life')

# %%
(a,b) = 'python', 'life'

# %%
[a, b] = ['python', 'life']

# %%
a = b = 'python'

# %%
# swap in python
a = 3
b = 5
a, b = b, a

# %%
a
# Out:
# 5

# %%
b
# Out:
# 3

# %%
# ex - False, because a and b is located differently
a = [1,2,3]
b = [1,2,3]
a is b
# Out:
# False
