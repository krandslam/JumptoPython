# %%
# exponent
a = 4.24E10
print(a)
# Out:
# 42400000000.0

# %%
a = 4.24e-10
print(a)
# Out:
# 4.24e-10

# %%
#Octal
a = 0o177 # Decimal: 7+8*7+1*8^2 = 127
print(a)
# Out:
# 127

# %%
#Hexadecimal
a = 0x8ff # Decimal: 8*16^2 + 15*16 + 15 = 2303
print(a)
# Out:
# 2303

# %%
# addition
a = 3
b = 4
a + b
# Out:
# 7

# %%
# multiplication
a*b
# Out:
# 12

# %%
#division
a/b
# Out:
# 0.75

# %%
# exponent
a**b # 3^4 = 81
# Out:
# 81

# %%
# remainder
7%4
# Out:
# 3

# %%
# quotient
7//4
# Out:
# 1

# %%
# ex
quo = 14 // 3
rem = 14 % 3

print(quo)
print(rem)
# Out:
# 4
# 2
