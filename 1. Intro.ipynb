# %%
# arithmetic operation
1 + 2
# Out:
# 3

# %%
3/2.4
# Out:
# 1.25

# %%
3*9
# Out:
# 27

# %%
# use variable
a = 1

# %%
b = 2

# %%
a + b
# Out:
# 3

# %%
# string
a = "Python"

# %%
print(a)
# Out:
# Python

# %%
# if
a = 3
if a > 1:
  print("a is greater than 1")
# Out:
# a is greater than 1

# %%
# for loop
for a in [1,2,3]:
  print(a)
# Out:
# 1
# 2
# 3

# %%
# while loop
i = 0
while i < 3:
  i = i + 1
  print(i)
# Out:
# 1
# 2
# 3

# %%
# add func
def add(a,b):
  return a+b

# %%
add(3,4)
# Out:
# 7
